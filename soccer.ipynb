# %%
#!pip install pygame

# %%
import pygame
import sys
from pygame.locals import *
import random

FPS = 60
MAX_WIDTH = 600
MAX_HEIGHT = 400


pygame.init()
clock = pygame.time.Clock()
screen = pygame.display.set_mode((MAX_WIDTH,MAX_HEIGHT))

class Player():
    lst = []
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def draw(self):
        return pygame.draw.circle(screen, (0,0,255),(self.x,self.y),20)
        
    def move(self):
        if pressed_keys[K_RIGHT]:
            if self.x < MAX_WIDTH -21:
                self.x += 5
        if pressed_keys[K_LEFT]:
            if self.x > 21:
                self.x -= 5
    def checkCollision():
        for p in Player.lst:
            if player.x + 20 == enemy.x - 20:
                player.x -= 5
                enemy.x += 5
            elif player.x - 20 == enemy.x + 20 :
                player.x += 5
                enemy.x -= 5
class Enemy():
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def draw(self):
        return pygame.draw.circle(screen, (255,0,0),(self.x,self.y),20)
        
def main():
    while True:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_SPACE:
                    print("space")
        clock.tick(FPS)
        screen.fill((255,255,255))
        global pressed_keys
        pressed_keys = pygame.key.get_pressed()
        enemy_rect = enemy.draw()
        player_rect = player.draw()
        player.move()
        Player.checkCollision()
        pygame.display.update()
        
    
        
enemy = Enemy(MAX_WIDTH/2,MAX_HEIGHT-40)
player = Player(MAX_WIDTH/2,MAX_HEIGHT-40)
Player.lst.append(enemy)
Player.lst.append(player)

if __name__ == '__main__':
    main()
